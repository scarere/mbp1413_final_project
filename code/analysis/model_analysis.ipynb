# %% [markdown]
# # Model Analysis

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
sys.path.append('/Users/scarere/Documents/UofT/OneDrive-UofT/mbp1413_final_project/code')
from utils.segment_metrics import IOU_eval
import torch
from utils.helper_functions import load_data
import numpy as np

# %% [markdown]
# ## Load Metrics

# %%
model_path = '../trained_models/rotation/rot_exp_sample/unet_rot_30_2'
save=False

# %%
train = pd.read_csv(os.path.join(model_path, 'train_metrics.csv'))
val = pd.read_csv(os.path.join(model_path, 'val_metrics.csv'))

# %% [markdown]
# ## Plot Loss

# %%
fig = plt.figure(figsize=(10, 8))
plt.title('Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.plot(train['epoch'], train['loss'])
plt.plot(val['epoch'], val['val_loss'])
plt.legend(['train', 'validation'])
# plt.ylim(top=1)
#plt.xlim(right=100)
#plt.vlines(14, ymin=0.25, ymax=1.2, colors='r', linestyles='dashed', linewidth=0.75)
#plt.vlines(10, ymin=0.25, ymax=1.2, colors='r', linestyles='dashed', linewidth=0.75)
if save:
    fig.savefig(os.path.join(model_path, 'loss.png'), dpi=300, bbox_inches='tight', facecolor='white')

# %% [markdown]
# ## Plot IoU

# %%
fig = plt.figure(figsize=(10, 8))
plt.plot(train['epoch'], train['IoU'])
plt.plot(val['epoch'], val['val_IoU'])
plt.title('IoU')
plt.legend(['train', 'val'])
#plt.ylim(bottom=0.6)
if save:
    fig.savefig(os.path.join(model_path, 'iou.png'), dpi=300, bbox_inches='tight', facecolor='white')
